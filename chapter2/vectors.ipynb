# %% [markdown]
# # Representing a Vector
#
# This demo shows a simple case of moving up the representational hierarchy to see how the first principle of the NEF generalizes from a simple (i.e., scalar - shown in the previous demo) to more complex (i.e., vector) cases.
#
# In nengo, ensembles of neurons represent information. In this example, we will represent a two-dimensional vector with a single ensemble of leaky integrate-and-fire neurons. Though we are considering the case of two-dimensional vector representation, but the ideas naturally generalize to any dimension

# %% [markdown]
# ## Step 1: Create the Model
#
# Our model consists of a single ensemble, which we will call `Neurons`. It will represent a two-dimensional signal.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import nengo

model = nengo.Network(label='2D Representation')
with model:
    # Our ensemble consists of 100 leaky integrate-and-fire neurons,
    # and represents a 2-dimensional signal
    neurons = nengo.Ensemble(100, dimensions=2)

# %% [markdown]
# ## Step 2: Create input for the model
#
# The signal that an ensemble represents varies over time. We will use a simple sine and cosine wave as examples of continuously changing signals.

# %%
import numpy as np
with model:
    # Create input nodes representing the sine and cosine signals
    sin = nengo.Node(output=np.sin)
    cos = nengo.Node(output=np.cos)

# %% [markdown]
# ## Step 3: Connect the Model Elements

# %%
with model:
    # The indices in neurons define which dimension the input will project to
    nengo.Connection(sin, neurons[0])
    nengo.Connection(cos, neurons[1])

# %% [markdown]
# ## Step 4: Add Probes to Collect Data
#
# Anything that is probed will collect the data it produces over time, allowing us to analyze and visualize it later. Let's collect all the data produced.

# %%
with model:
    sin_probe = nengo.Probe(sin, 'output')
    cos_probe = nengo.Probe(cos, 'output')
    neurons_probe = nengo.Probe(neurons, 'decoded_output', synapse=0.01)

# %% [markdown]
# ## Step 5: Run the model
#
# In order to run the model, we have to create a simulator. Then, we can run that simulator over and over again without affecting the original model.

# %%
# Create our simulator
sim = nengo.Simulator(model)
# Run it for 5 seconds
sim.run(5)

# %% [markdown]
# ## Step 6: Plot the Results

# %%
# Plot the inputs to the ensemble
plt.plot(sim.trange(), sim.data[sin_probe], 'r', label="Sine Input")
plt.plot(sim.trange(), sim.data[cos_probe], 'k', label="Cosine Input")
plt.legend(loc="best")
plt.xlabel('time [s]');

# Plot the decoded output of the ensemble
plt.figure()
plt.plot(sim.trange(), sim.data[neurons_probe], label="Decoded output")
plt.plot(sim.trange(), sim.data[sin_probe], 'r', label="Sine Input")
plt.plot(sim.trange(), sim.data[cos_probe], 'k', label="Cosine Input")
plt.legend(loc="best")
plt.xlabel('time [s]');
